# %%
import re
text = """{{also|Appendix:Variations of "it"}}
==English==


===Alternative forms===
* {{context|dialectal|lang=en}} {{l|en|hit}}


* {{qualifier|stressed}} {{enPR|ĭt}}, {{IPA|/ɪt/|lang=en}}
* {{qualifier|dialectal}} {{IPA|/ɪt̚ʔ/|/ɪʔ/|lang=en}}


* {{rhymes|ɪt|lang=en}}
* {{qualifier|unstressed}} {{enPR|ət}}, {{IPA|/ət/|lang=en}}
* {{homophones|lang=en|at}} {{qualifier|unstressed}}

===Etymology 1===
From {{etyl|enm|en}} {{m|enm|it}}, {{m|enm|hit}} ( > English dialectal {{m|enm|hit||it}}), from {{etyl|ang|en}} {{m|ang|hit||it}}, from {{etyl|gem-pro|en}} {{m|gem-pro|*hit||this, this one}}, from {{etyl|ine-pro|en}} {{m|ine-pro|*ḱe-}}, {{m|ine-pro|*ḱey-||this, here}}. Cognate with {{etyl|fy|-}} {{m|fy|it||it}}, {{etyl|nds|-}} {{m|nds|it||it}}, {{etyl|nl|-}} {{m|nl|het||it}}, {{etyl|de|-}} {{m|de|es||it}}. More at {{l|en|he}}.

====Alternative forms====
* [[itt]] {{qualifier|obsolete}}

====Pronoun====
{{en-pron|subjective and [[objective case|objective]]|it|reflexive and intensive|itself|[[possessive adjective]] and [[noun]]|its}}

# The third-person singular personal pronoun used to refer to an inanimate object, to an inanimate thing with no or unknown sex or gender.
#: ''Put '''it''' over there.''
#: ''Take each day as '''it''' comes.''
# The third-person singular personal pronoun used to refer to an animate entity of unknown gender.
#: ''She took the baby and held '''it''' in her arms.''
#* '''1847''', Charlotte Brontë, ''Jane Eyre'', Chapter IV:
#*: A child cannot quarrel with '''its''' elders, as I had done; cannot give '''its''' furious feelings uncontrolled play, as I had given mine, without experiencing afterwards the pang of remorse and the chill of reaction.
# Used to refer to oneself when identifying oneself, often on the phone, but not limited to this situation.
#: '''''It''''s me. John.''
# The impersonal pronoun, used without referent as the subject of an impersonal verb or statement. (known as the [[dummy pronoun]] or [[weather it]])
#: '''''It''' is nearly 10 o’clock.''
#: '''''It'''’s very cold today.''
#: '''''It'''’s lonely without you.''
# The impersonal pronoun, used as a placeholder for a delayed subject, or less commonly, object. (known as the [[dummy pronoun]] or, more formally in linguistics, a [[syntactic expletive]])
#: '''''It''' is easy to see how she would think that.''
#: ''I find '''it''' odd that you would say that.''
#: ''He saw to '''it''' that everyone would vote for him.''
# {{context|obsolete|relative|lang=en}} That which; [[what]].
#* '''1643''', {{w|Thomas Browne}}, ''Religio Medici'', II.2:
#*: In briefe, I am content, and what should providence add more? Surely this is '''it''' wee call Happinesse, and this doe I enjoy [...].

: ''See'' [[Wiktionary:English inflection]] for other personal pronouns.

=====Quotations=====
* {{seeCites}}

=====Derived terms=====
{{rel-top|Derived terms}}
* [[buy it]]
* [[do it]]
* [[for it]]
* [[move it]]
* [[that's it|that’s it]]
* [[watch it]]
{{rel-bottom}}

=====See also=====
{{rel-top3|English’s other subject and object pronouns}}
* [[he]]
* [[her]]
* [[him]]
* [[I]]
* [[me]]
{{rel-mid3}}
* [[she]]
* [[thee]]
* [[them]]
* [[they]]
* [[thou]]
{{rel-mid3}}
* [[us]]
* [[we]]
* [[ye]]
* [[you]]
{{rel-bottom}}

=====Translations=====
{{trans-top|subject — inanimate thing}}
* Afrikaans: {{t+|af|dit}}
* Albanian: {{t+|sq|ai}}, {{t+|sq|ajo}}
* Arabic: {{t+|ar|هو|tr=húwa|m}}, {{t+|ar|هي|tr=híya|f}}
* Armenian: {{t|hy|դա}}
* Azeri: {{t+|az|o}}
* Belarusian: {{t|be|яно́|n}}, {{t+|be|гэ́та|n}}
* Bulgarian: {{t-check|bg|той|m}}, {{t-check|bg|тя|f}}, {{t-check|bg|то|n}}
* Catalan: {{t+check|ca|el|m}}, {{t+check|ca|la|f}}, {{qualifier|usually not translated}}
* Chinese:
*: Mandarin: {{t+|cmn|它|tr=tā|sc=Hani}}, {{qualifier|classical}} {{t+|cmn|之|tr=zhī|sc=Hani}}, {{qualifier|this}} {{t+|cmn|這|sc=Hani}}, {{t+|cmn|这|tr=zhè, zhèi|sc=Hani}}, {{qualifier|that}} {{t+|cmn|那|tr=nà, nèi|sc=Hani}}, {{qualifier|used for animals, variant of 它}} {{t+|cmn|牠|tr=tā|sc=Hani}}
* Cornish: {{t|kw|ev|m}}, {{t|kw|hi|f}}
* Czech: {{t+|cs|to}}
* Danish: {{t+|da|det}}
* Dutch: {{t+|nl|het}} {{qualifier|for neutral nouns}}, {{t+|nl|hij}} {{qualifier|for gendered nouns}}
* Erzya: {{t|myv|сон}}
* Esperanto: {{t+|eo|ĝi}}
* Estonian: {{t+|et|see}}, {{t+|et|too}}
* Faroese: {{t|fo|tað|n}}
* Finnish: {{t+|fi|se}}
* French: {{t+|fr|le|m}}, {{t+|fr|la|f}}, {{t+|fr|il|m}}, {{t+|fr|elle|f}}
* Georgian: {{t+|ka|ის}}
* German: {{t+|de|er|m}}, {{t+|de|sie|f}}, {{t+|de|es|n}}
* Greek: {{t+|el|το}}, {{t+|el|αυτό}} (sometimes not translated)
* Greenlandic: {{t|kl|una}}
* Hawaiian: {{t|haw|ia}}
* Hebrew: {{t+|he|זה}}, {{t+|he|זאת}}
* Hindi: {{qualifier|he, she and it}} {{t|hi|वह|tr=vah}}, {{t|hi|यह|tr=yah}}
* Hopi: {{t|hop|pam}}
* Hungarian: {{t+|hu|az}}
* Icelandic: {{t+|is|það}}
* Ido: {{t+|io|ol}}, {{t+|io|olu}}
* Interlingua: {{t|ia|lo}}, {{t|ia|illo}}
* Irish: {{t+|ga|sé|m}} {{qualifier|conjunctive}}, {{t|ga|é|m}} {{qualifier|disjunctive}}, {{t|ga|sí|f}} {{qualifier|conjunctive}}, {{t|ga|í|f}} {{qualifier|disjunctive}}, {{qualifier|predicate of copula}} {{t|ga|ea}}
*: Old Irish: {{t|sga|ed}}
* Italian: {{t+|it|esso}}, {{t+|it|essa}}, {{t+|it|lo}}, {{t+|it|la}}
* Japanese: {{t+|ja|それ|tr=soré}}
* Khmer: {{t+|km|វា|tr=vie|sc=Khmr}}
* Korean: {{t+|ko|그것|tr=geugeot}}
* Lao: {{t|lo|ມັນ|sc=Laoo}}
* Latin: {{t|la|id}}
* Latvian: {{t-needed|lv}}
{{trans-mid}}
* Macedonian: {{t+|mk|тоа|n}}
* Maltese: {{t+|mt|hu|m}}, {{t+|mt|hi|f}}
* Moksha: {{t|mdf|сон}}
* Mongolian: {{t+|mn|тэр|sc=Cyrl}}, {{t|mn|уун|sc=Cyrl}}, {{t|mn|туун|sc=Cyrl}}, {{t|mn|энэ|sc=Cyrl}}
* Motu: {{t|meu|ia}}
* Northern Sami: {{t|se|son}}
* Norwegian: {{t+|no|det}}
* Novial: {{t|nov|lu}}, {{t|nov|lum}}
* Old Church Slavonic: {{t|cu|оно|sc=Cyrs}}
* Old English: {{t+|ang|hit}}, {{t+|ang|þæt}}
* Persian: {{t+|fa|او|tr=u}}
* Pipil: {{t|ppl|yaja}}, {{t|ppl|yaha}}
* Polish: {{t+|pl|to|n}}
* Portuguese: {{t+|pt|ele|m}}, {{t+|pt|ela|f}}, {{t+|pt|isso}}
* Rapa Nui: {{t|rap|ia}}
* Romanian: {{t-needed|ro}}
* Russian: {{t+|ru|он}}, {{t+|ru|она́}}, {{t+|ru|оно́}}, {{t+|ru|э́то}}
* Sardinian: {{t|sc|issu}}
* Scottish Gaelic: {{t|gd|e|m}} {{qualifier|non-emphatic}}, {{t|gd|esan|m}} {{qualifier|emphatic}}, {{t|gd|i|f}} {{qualifier|non-emphatic}}, {{t|gd|ise|f}} {{qualifier|emphatic}}
* Serbo-Croatian:
*: Cyrillic: {{t|sh|оно|n}}
*: Roman: {{t+|sh|ono|n}}
* Sicilian: {{t+|scn|issu}}
* Sinhalese: {{t|si|එයා|sc=Sinh}}, {{qualifier|of animals}} {{t+|si|ඌ|sc=Sinh}}, {{t|si|ඒක|sc=Sinh}}
* Slovak: {{t|sk|ono}}
* Slovene: {{t|sl|ôno}}
* Sorbian:
*: Lower Sorbian: {{t|dsb|wóno}}
* Spanish: {{t+|es|ello}}, {{t+|es|él}}, {{t+|es|ella}}, {{t+|es|eso}}, {{t+|es|lo}} (often not translated)
* Swedish: {{t+|sv|den|c}}, {{t+|sv|det|n}}
* Taos: {{t|twf|ą́wąną}}
* Thai: {{t+|th|มัน|tr=man|sc=Thai}}
* Turkish: {{t+|tr|o}}
* Ukrainian: {{t+|uk|воно́|n}}
* Urdu: {{t|ur|وہ|tr=vah|sc=ur-Arab}}, {{t|ur|يہ|tr=yah|sc=ur-Arab}}
* Vietnamese: {{t+|vi|nó}}
* Volapük: {{t+|vo|on}}
* Welsh: {{t|cy|ef|m}}, {{t|cy|hi|f}}
* West Frisian: {{t+|fy|it}}
* Yiddish: {{t|yi|עס|tr=es|sc=Hebr}}
* Zulu: {{t|zu|yena|c1}}, {{t|zu|wona|c3}}, {{t|zu|lona|c5}}, {{t|zu|sona|c7}}, {{t|zu|yona|c9}}, {{t|zu|lona|c11}}
* ǃXóõ: {{t|nmn|èh}}, {{qualifier|emphatic}} {{t|nmn|èhʻè}}, {{t|nmn|ãh}}, {{qualifier|emphatic}} {{t|nmn|ãhʻã}}, {{t|nmn|ìh}}
{{trans-bottom}}

{{trans-top|object}}
* Afrikaans: {{t+|af|dit}}
* Bulgarian: {{t|bg|него}}, {{t|bg|го|m|n}} {{qualifier|accusative case}}, {{t|bg|на него}}, {{t|bg|нему}}, {{t|bg|му|m|n}} {{qualifier|dative case}}, {{t|bg|нея}}, {{t|bg|я|f}} {{qualifier|accusative case}}, {{t|bg|на нея}}, {{t|bg|ней}}, {{t+|bg|ѝ|f}} {{qualifier|dative case}}
* Chinese:
*: Mandarin: {{t+|cmn|这}}, {{t+|cmn|那|tr=nà, nèi}}, {{t+|cmn|它|tr=tā}}, {{t+|cmn|之|tr=zhī}}
* Cornish: {{t|kw|'n|m}}, {{t|kw|'s|f}}
* Czech: {{t|cs|toho}}, {{t|cs|tomu}}, {{t+|cs|to}}
* Dutch: {{t+|nl|het}}, {{t+|nl|er}}
* Esperanto: {{t+|eo|ĝin}}
* Finnish: {{t+|fi|sen}} {{qualifier|in active clauses, accusative}}, {{t+|fi|sitä}} {{qualifier|in active clauses, partitive}}, {{t+|fi|se}} {{qualifier|in passive clauses, accusative}}, {{t+|fi|sitä}} {{qualifier|in passive clauses, partitive}}
* French: {{t+|fr|le|m}}
* German: {{t+|de|es}}
* Greek: {{t+|el|το}}
* Hebrew: {{t-needed|he}}
* Hungarian: {{t+|hu|az}}
* Ido: {{t+|io|ol}}, {{t+|io|olu}}
* Irish: {{t|ga|é|m}}, {{t|ga|í|f}}
*: Old Irish: {{t|sga|a-}}, {{t|sga|id-}}, {{t|sga|did-}}, {{t|sga|d-}}, {{t|sga|-i}}, {{t|sga|-it}}
* Italian: {{t+|it|lo}}
* Japanese: {{t+|ja|それ|tr=soré}}
* Korean: {{t+|ko|그것|tr=geugeot}}
* Lao: {{t|lo|ມັນ|sc=Laoo}}
{{trans-mid}}
* Latin: {{t|la|id}}, {{t|la|illud}}, {{t|la|hoc}}
* Macedonian: {{t|mk|го}} {{qualifier|short form}}, {{t+|mk|него}} {{qualifier|long form}}
* Mongolian: {{t|mn|үүнийг|sc=Cyrl}}
* Norwegian: {{t+|no|den}}
* Novial: {{t|nov|lu}}, {{t|nov|lum}}
* Old English: {{t+|ang|hit}}, {{t+|ang|þæt}}
* Persian: {{t|fa|او را|tr=u rā}}
* Pipil: {{t|ppl|ki-}}, {{t|ppl|k-}}
* Portuguese: {{t+|pt|o|m}}, {{t+|pt|a|f}}
* Russian: {{t+|ru|его́|m|n}} {{qualifier|genitive case}}, {{t+|ru|ему́|m|n}} {{qualifier|dative case}}, {{t+|ru|его́|m|n}} {{qualifier|accusative case}}, {{t+|ru|им|m|n}} {{qualifier|instrumental case}}, {{t+|ru|нём|m|n}} {{qualifier|prepositional case}}
*: {{t+|ru|её|f}} {{qualifier|genitive case}}, {{t+|ru|ей|f}} {{qualifier|dative case}}, {{t+|ru|её|f}} {{qualifier|accusative case}}, {{t+|ru|е́ю}} / {{t+|ru|ей|f}} {{qualifier|instrumental case}}, {{t+|ru|ней|f}} {{qualifier|prepositional case}}
* Sorbian:
*: Lower Sorbian: {{t|dsb|jo}}
* Spanish: {{t+|es|le}}, {{t+|es|la}}, {{t+|es|lo}}, {{t+|es|ello}}, {{t+|es|eso}}
* Swedish: {{t+|sv|den|c}}, {{t+|sv|det|n}}
* Thai: {{t+|th|มัน|tr=man}}
* West Frisian: {{t+|fy|it}}
* Zulu: {{t|zu|yena|c1}}, {{t|zu|wona|c3}}, {{t|zu|lona|c5}}, {{t|zu|sona|c7}}, {{t|zu|yona|c9}}, {{t|zu|lona|c11}}, {{t|zu|bona|c14}}, {{t|zu|khona|c15|c17}}
* ǃXóõ: {{t|nmn|èh}}, {{qualifier|emphatic}} {{t|nmn|èhʻè}}, {{t|nmn|ãh}}, {{qualifier|emphatic}} {{t|nmn|ãhʻã}}, {{t|nmn|ìh}}
{{trans-bottom}}

{{trans-top|subject of impersonal statement}}
* Catalan: {{not used|ca}}
* Dutch: {{t+|nl|het}}
* Faroese: {{t|fo|tað|n}}
* Finnish: {{not used|fi}}
* French: {{t+|fr|ce}}
* German: {{t+|de|es}}
* Hebrew: {{t-needed|he}}
{{trans-mid}}
* Irish: {{t+|ga|sé}}
* Latin: {{t|la|id}}, {{t|la|illud}}, {{t|la|hoc}}
* Novial: {{not used|nov}}
* Portuguese: {{not used|pt}}
* Spanish: {{not used|es}}
* Swedish: {{t+|sv|det}}
* Zulu: {{t|zu|khona|c17}}
{{trans-bottom}}

{{trans-top|impersonal pronoun, used without referent}}
* French: {{t+|fr|il}}
* German: {{t+|de|es|n}}
{{trans-mid}}
* Latin: {{t|la|id}}, {{t|la|illud}}, {{t|la|hoc}}
* Spanish: {{not used|es}}
{{trans-bottom}}

{{trans-top|impersonal pronoun, used as a placeholder}}
* French: {{t+|fr|ce}}, {{t+|fr|ça}}, {{t+|fr|cela}}
* Latin: {{t|la|id}}, {{t|la|illud}}, {{t|la|hoc}}
{{trans-mid}}
* Spanish: {{not used|es}}
{{trans-bottom}}

{{checktrans-top}}
* Udmurt: {{t-check|udm|со|sc=Cyrl}}
{{trans-mid}}
* Vietnamese: {{t+check|vi|nó}}
{{trans-bottom}}

====Noun====
{{en-noun}}

# One who is neither a [[he]] nor a [[she]]; a [[creature]]; a [[dehumanize]]d being.
#* '''1995''', Neil Weiner, Sharon E. Robinson Kurpius, ''Shattered innocence'' (page 8)
#*: Too often, children become an "'''it'''" in their homes and their humanness is devalued.
#* '''1920''', {{w|Herman Cyril McNeile}}, ''Bulldog Drummond'' Chapter 1
#*: His master glanced up quickly, and removed the letter from his hands. "I'm surprised at you, James," he remarked severely. "A secretary should control itself. Don't forget that the perfect secretary is an '''it''': an automatic machine—a thing incapable of feeling.…"
# The [[person]] who [[chase]]s and tries to [[catch]] the other [[player]]s in the [[playground]] game of [[tag]].
#: ''In the next game, Adam and Tom will be '''it'''…''
#* '''2000''', Katherine T. Thomas, Amelia M. Lee, Jerry R. Thomas, ''Physical education for children'' (page 464)
#*: When there are only two children left who haven't been tagged, I will stop the game, and we will start over with those children starting as the '''Its'''.
# {{context|British|uncountable|lang=en}} The game of [[tag]].
#: ''Let's play '''it''' at breaktime.''

====Adjective====
{{en-adj|-}}

# {{context|colloquial|lang=en}} most [[fashionable]].
#* ''Vibe'', Vol. 15, No. 9, p. 202, September 2007:
#*: ''Going away for the weekend and feel the need to profile en route? This is the "'''it'''" bag.''
#* David Germain, [http://today.msnbc.msn.com/id/36481998/ns/entertainment-movies/ ''Hilarious ‘Kick-Ass’ delivers bloody fun''], Associated Press, 2010:
#*: ''With Hit Girl, Moretz is this year's '''It''' Girl, alternately sweet, savage and scary.''

===Etymology 2===

====Abbreviation====
{{head|en|abbreviation}}

# {{qualifier|language}} [[Italian]].
# [[Italy]].

=====Derived terms=====
* [[gin and it]], [[gin-and-It]]

=====See also=====
* [[IT]]

====Statistics====
* {{rank|his|with|is|13|it|for|as|had}}

===Anagrams===
* [[ti#English|ti]], [[TI#English|TI]], [[Ti.#English|Ti.]]

[[Category:100 English basic words]]
[[Category:1000 English basic words]]
[[Category:English personal pronouns]]
[[Category:English third person pronouns]]
[[Category:English two-letter words]]

----

==Azeri==

===Etymology===
From {{etyl|trk-pro|az}} {{m|trk-pro|*it}}, {{m|trk-pro|*ït}}.

===Noun===
{{head|az|noun|Cyrillic spelling|ит}}

# [[dog]]

===Verb===
{{head|az|verb form|Cyrillic spelling|ит}}

# [[get lost]] {{qualifier|imperative}}

----

==Crimean Tatar==

===Etymology===
From {{etyl|trk-pro|crh}} {{m|trk-pro|*it}}, {{m|trk-pro|*ït}}.

===Noun===
{{head|crh|noun}}

# [[dog]]

====Synonyms====
* [[köpek]]

====References====
* {{R:Useinov-Mireev 2002}}

----

==Greenlandic==

===Affix===
{{head|kl|morpheme}}

# indicates a state of being without something.
#:''maani nipa'''a'''ppoq'' - It is quiet here.
#:''siku'''i'''ppoq'' - There is no ice.

----

==Latin==

===Verb===
{{la-verb-form|it}}

# {{inflection of|eō||3|s|pres|act|ind|lang=la}}

----

==Middle Dutch==


* {{IPA|lang=dum|/ɪt/}}

===Pronoun===
{{head|dum|pronoun}}

# {{alternative form of|het|lang=dum}}

----

==Old Irish==

===Alternative forms===
* {{sense|2nd sg.}} {{l|sga|at}}

===Verb===
{{head|sga|verb form}}

# {{inflection of|is||2|s|pres|ind|lang=sga}}
# {{inflection of|is||3|p|pres|ind|lang=sga}}

----

==Old Saxon==

===Etymology===
From {{etyl|gem-pro|osx}} {{m|gem-pro|*it}}.

===Pronoun===
{{head|osx|pronoun|g=n}}

# [[#English|it]]

====Declension====
{{osx-decl-ppron}}

====Descendants====
* Low German: {{l|nds|et}}

----

==Turkish==

===Etymology===
From {{etyl|otk|tr}} ''ıt'' (“dog”), from {{etyl|trk-pro|tr}} {{m|trk-pro|*īt}}, {{m|trk-pro|*ıyt}}, {{m|trk-pro|*ɨt}}, {{m|trk-pro|*it}}.

===Noun===
{{tr-noun|i|ler}}

# [[dog]]
# a word for [[aspersion]]

====Declension====
{{tr-noun-c|e|t|pred=+|poss=+}}

====Usage notes====
It's generally used in countryside when meant "dog". But if the dog isn't loved, it can be said "it" for it, too.

===Verb===
{{head|tr|verb form}}

# {{second-person singular imperative of|itmek|lang=tr}} (to [[push]])

----

==Turkmen==

===Etymology===
From {{etyl|otk|tk}} ''ıt'' (“dog”), from {{etyl|trk-pro|tk}} {{m|trk-pro|*īt}}, {{m|trk-pro|*ıyt}}, {{m|trk-pro|*ɨt}}, {{m|trk-pro|*it}}.

===Noun===
{{tk-noun|idi|ler}}

# [[dog]]

====Declension====
{{tk-decl-noun-man|it|itler|idi|itleri|idiň|itleriň|ide|itlere|itde|itlerde|itden|itlerden}}

----

==Uzbek==

===Etymology===
From {{etyl|trk-pro|uz}} {{m|trk-pro|*ɨt}}, {{m|trk-pro|*it}}

===Noun===
{{uz-noun}}

# [[dog]]

----

==Volapük==

===Determiner===
{{head|vo|determiner}}

# {{context|with a personal pronoun|lang=vo}} [[self]]; [[myself]]; [[yourself]]; [[himself]]; [[herself]]; [[itself]]; [[ourselves]]; [[themselves]]; {{non-gloss definition|emphasises the identity or singularity of the modified noun phrase}}

----

==West Frisian==

===Article===
{{head|fy|article|g=n}}

# [[the]] (the definite article that is placed before neuter nouns. Non-neuter (common gender) nouns take the article ''[[de]]'').

===Pronoun===
{{head|fy|pronoun|personal pronoun}}

# [[#English|it]]: the third-person singular, referring to something neutral, genderless.














































[[simple:it]]"""

# %%
split = re.split(r'\n==([^=]*?)==\n', text)
print split[split.index("English") + 1].strip()
# Out:
# ===Alternative forms===
# * {{context|dialectal|lang=en}} {{l|en|hit}}
#
#
# * {{qualifier|stressed}} {{enPR|ĭt}}, {{IPA|/ɪt/|lang=en}}
# * {{qualifier|dialectal}} {{IPA|/ɪt̚ʔ/|/ɪʔ/|lang=en}}
#
#
# * {{rhymes|ɪt|lang=en}}
# * {{qualifier|unstressed}} {{enPR|ət}}, {{IPA|/ət/|lang=en}}
# * {{homophones|lang=en|at}} {{qualifier|unstressed}}
#
# ===Etymology 1===
# From {{etyl|enm|en}} {{m|enm|it}}, {{m|enm|hit}} ( > English dialectal {{m|enm|hit||it}}), from {{etyl|ang|en}} {{m|ang|hit||it}}, from {{etyl|gem-pro|en}} {{m|gem-pro|*hit||this, this one}}, from {{etyl|ine-pro|en}} {{m|ine-pro|*ḱe-}}, {{m|ine-pro|*ḱey-||this, here}}. Cognate with {{etyl|fy|-}} {{m|fy|it||it}}, {{etyl|nds|-}} {{m|nds|it||it}}, {{etyl|nl|-}} {{m|nl|het||it}}, {{etyl|de|-}} {{m|de|es||it}}. More at {{l|en|he}}.
#
# ====Alternative forms====
# * [[itt]] {{qualifier|obsolete}}
#
# ====Pronoun====
# ...

# %%
print re.sub(r'\n\s+\n', '\n\n', text)
# Out:
# {{also|Appendix:Variations of "it"}}
# ==English==
#
# ===Alternative forms===
# * {{context|dialectal|lang=en}} {{l|en|hit}}
#
# * {{qualifier|stressed}} {{enPR|ĭt}}, {{IPA|/ɪt/|lang=en}}
# * {{qualifier|dialectal}} {{IPA|/ɪt̚ʔ/|/ɪʔ/|lang=en}}
#
# * {{rhymes|ɪt|lang=en}}
# * {{qualifier|unstressed}} {{enPR|ət}}, {{IPA|/ət/|lang=en}}
# * {{homophones|lang=en|at}} {{qualifier|unstressed}}
#
# ===Etymology 1===
# From {{etyl|enm|en}} {{m|enm|it}}, {{m|enm|hit}} ( > English dialectal {{m|enm|hit||it}}), from {{etyl|ang|en}} {{m|ang|hit||it}}, from {{etyl|gem-pro|en}} {{m|gem-pro|*hit||this, this one}}, from {{etyl|ine-pro|en}} {{m|ine-pro|*ḱe-}}, {{m|ine-pro|*ḱey-||this, here}}. Cognate with {{etyl|fy|-}} {{m|fy|it||it}}, {{etyl|nds|-}} {{m|nds|it||it}}, {{etyl|nl|-}} {{m|nl|het||it}}, {{etyl|de|-}} {{m|de|es||it}}. More at {{l|en|he}}.
#
# ====Alternative forms====
# * [[itt]] {{qualifier|obsolete}}
#
# ====Pronoun====
# ...
